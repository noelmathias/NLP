# %%
paragraph = '''
The invention of the printing press by Johannes Gutenberg in the 15th century 
acted as a massive catalyst for societal change, 
fundamentally altering how information was disseminated across Europe.
Before this, books were hand-copied, rare, and owned only by the elite, 
which meant that knowledge was heavily controlled by institutions like the Church and the monarchy.
With the ability to produce texts rapidly and relatively cheaply, knowledge became accessible to the masses,
fostering a rise in literacy rates among the middle class. 
This democratization of information meant that new ideas,
particularly those concerning science, philosophy, and religion, 
could spread across borders in weeks rather than years.
The Protestant Reformation, for example, gained immense momentum because Martin Luther’s ideas 
could be printed and distributed quickly, 
bypassing traditional gatekeepers of knowledge. Furthermore, 
the printing press allowed for the standardization of languages and the preservation of scientific knowledge, 
which laid the groundwork for the Scientific Revolution.
Ultimately, the shift from a scribal culture to a print culture meant that power dynamics shifted,
as the monopoly on information was broken and public discourse began to emerge.
'''

# %%
import nltk

# %%
 print('\n'.join(sentences))
# Out:
# The invention of the printing press by Johannes Gutenberg in the 15th century
# acted as a massive catalyst for societal change,
# fundamentally altering how information was disseminated across Europe.
# Before this, books were hand-copied, rare, and owned only by the elite,
# which meant that knowledge was heavily controlled by institutions like the Church and the monarchy.
# With the ability to produce texts rapidly and relatively cheaply, knowledge became accessible to the masses,
# fostering a rise in literacy rates among the middle class.
# This democratization of information meant that new ideas,
# particularly those concerning science, philosophy, and religion,
# could spread across borders in weeks rather than years.
# The Protestant Reformation, for example, gained immense momentum because Martin Luther’s ideas
# could be printed and distributed quickly,
# bypassing traditional gatekeepers of knowledge.
# Furthermore,
# ...

# %%
from nltk.corpus import stopwords
sentences = nltk.sent_tokenize(paragraph)

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\noelm\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
## to find POS tag
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in (stopwords.words("english"))]
    #sentences[i] = ' '.join(words)  #converting list of words into sentences
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('The', 'DT'), ('invention', 'NN'), ('printing', 'VBG'), ('press', 'NN'), ('Johannes', 'NNP'), ('Gutenberg', 'NNP'), ('15th', 'JJ'), ('century', 'NN'), ('acted', 'VBD'), ('massive', 'JJ'), ('catalyst', 'NN'), ('societal', 'JJ'), ('change', 'NN'), (',', ','), ('fundamentally', 'RB'), ('altering', 'VBG'), ('information', 'NN'), ('disseminated', 'VBN'), ('across', 'IN'), ('Europe', 'NNP'), ('.', '.')]
# [('Before', 'IN'), (',', ','), ('books', 'NNS'), ('hand-copied', 'JJ'), (',', ','), ('rare', 'JJ'), (',', ','), ('owned', 'VBD'), ('elite', 'RB'), (',', ','), ('meant', 'VBD'), ('knowledge', 'NN'), ('heavily', 'RB'), ('controlled', 'VBD'), ('institutions', 'NNS'), ('like', 'IN'), ('Church', 'NNP'), ('monarchy', 'NN'), ('.', '.')]
# ...

# %% [markdown]
# Taj mahal is a beautiful monument

# %%
text = "Taj mahal is a beautiful monument".split()
print(text)
# Out:
# ['Taj', 'mahal', 'is', 'a', 'beautiful', 'monument']

# %%
print(nltk.pos_tag(text))      #parameter for "pos_tag" should be list of words and not words
# Out:
# [('Taj', 'NNP'), ('mahal', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('monument', 'NN')]
