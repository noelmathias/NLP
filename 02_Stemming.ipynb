# %%
from nltk.stem import PorterStemmer

# %%
words =["wording", "cats", "playing", "eaten", "writes", "programs", "history"]

# %%
stemmimg = PorterStemmer()

# %%
for word in words:
    print(word+"--->"+stemmimg.stem(word))
# Out:
# wording--->word
# cats--->cat
# playing--->play
# eaten--->eaten
# writes--->write
# programs--->program
# history--->histori

# %% [markdown]
# #### RegexpStemmer

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# #### Snowball

# %%
from nltk.stem import SnowballStemmer

# %%
snowball_stemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word+"---->"+snowball_stemmer.stem(word))
# Out:
# wording---->word
# cats---->cat
# playing---->play
# eaten---->eaten
# writes---->write
# programs---->program
# history---->histori

# %%
snowball_stemmer.stem('goes')  #misleading
# Out:
# 'goe'
